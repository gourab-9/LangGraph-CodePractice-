# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

load_dotenv(override=True)
model = ChatOpenAI()

# %%
# Define State

class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
# Graph Setup
graph = StateGraph(BlogState)

# Add nodes
graph.add_node("create_outline", create_outline)
graph.add_node("create_blog", create_blog)

# Add edges
graph.add_edge(START, "create_outline")
graph.add_edge("create_outline", "create_blog")
graph.add_edge("create_blog", END)

# %%
workflow = graph.compile()

initial_state = {"title": "Rise of AI in India"}
final_state = workflow.invoke(initial_state)
print(final_state["outline"])
print(final_state["content"])
# Out:
# I. Introduction
#     A. Brief overview of AI technology
#     B. Importance of AI in various industries
#     C. Growing use of AI in India
# II. History of AI in India
#     A. Early developments in AI in India
#     B. Adoption of AI in different sectors
# III. Impact of AI on Indian economy
#     A. Job creation and automation in industries
#     B. Economic growth and productivity
# IV. AI advancements in Indian healthcare
#     A. Use of AI in diagnostic tools and medical imaging
#     B. Improving patient care and treatment outcomes
# V. AI in agriculture and rural development
#     A. Applications of AI technology in agriculture
#     B. Role of AI in improving farming practices and increasing yield
# VI. Challenges and opportunities in AI adoption in India
#     A. Infrastructure and data security concerns
#     B. Government initiatives and policies promoting AI
# VII. Future of AI in India
#     A. Potential for growth and innovation in AI technology
#     B. Role of Indian startups in AI development
# VIII. Conclusion
#     A. Summary of key points
#     B. The promising future of AI in India
# In recent years, artificial intelligence (AI) has emerged as a transformative technology with the potential to revolutionize various industries. With its ability to analyze large amounts of data, make decisions, and perform tasks that typically require human intelligence, AI has become a key driver of innovation and efficiency. In India, the rise of AI has been significant, with businesses and organizations increasingly integrating AI into their operations to stay competitive in the global market.
#
# I. Introduction
#
# A. Brief overview of AI technology
# Artificial intelligence refers to the development of computer systems that can perform tasks that normally require human intelligence, such as visual perception, speech recognition, decision-making, and language translation. AI technologies include machine learning, natural language processing, neural networks, and robotics.
#
# B. Importance of AI in various industries
# AI has the potential to revolutionize industries such as healthcare, finance, agriculture, manufacturing, and transportation by improving efficiency, productivity, and decision-making. Companies are using AI to automate repetitive tasks, analyze big data, enhance customer service, and innovate new products and services.
#
# C. Growing use of AI in India
# India has seen a significant increase in the adoption of AI across various sectors. From startups to large corporations, businesses are leveraging AI technologies to streamline operations, improve customer experience, and drive growth. The Indian government has also recognized the importance of AI and has taken steps to promote its development and adoption in the country.
#
# II. History of AI in India
#
# A. Early developments in AI in India
# India has a rich history in the field of AI, with research institutes and universities at the forefront of AI research and development. The Indian Institute of Technology (IIT), Indian Statistical Institute (ISI), and Indian Institute of Science (IISc) have played a pivotal role in advancing AI technologies in the country.
#
# B. Adoption of AI in different sectors
# Various industries in India have embraced AI technology to improve efficiency and competitiveness. Healthcare companies are using AI for predictive analytics, drug discovery, and personalized medicine. Financial institutions are leveraging AI for fraud detection, risk assessment, and customer service. E-commerce companies are employing AI for recommendation engines, inventory management, and supply chain optimization.
#
# III. Impact of AI on Indian economy
#
# A. Job creation and automation in industries
# While AI has the potential to automate routine tasks and improve productivity, there are concerns about job displacement and the impact on the labor market. However, AI is also creating new job opportunities in emerging fields such as data science, machine learning, and AI engineering.
#
# B. Economic growth and productivity
# AI has the potential to boost economic growth by increasing productivity, driving innovation, and enhancing competitiveness. By leveraging AI technologies, Indian businesses can optimize processes, reduce costs, and deliver better products and services to customers.
#
# IV. AI advancements in Indian healthcare
#
# A. Use of AI in diagnostic tools and medical imaging
# AI technologies like machine learning and deep learning are being used to develop diagnostic tools for early detection of diseases and medical imaging for accurate diagnosis. AI algorithms can analyze medical images, patient data, and genetic information to help physicians make better treatment decisions.
#
# B. Improving patient care and treatment outcomes
# AI is improving patient care by enabling personalized treatment plans, predicting disease progression, and optimizing healthcare delivery. AI-powered chatbots and virtual assistants are also providing patients with access to healthcare information and support services.
#
# V. AI in agriculture and rural development
#
# A. Applications of AI technology in agriculture
# AI is transforming the agriculture sector by providing farmers with actionable insights, weather forecasting, crop monitoring, and pest detection. AI-powered drones and sensors are being used to collect data on soil quality, crop health, and water usage to optimize farming practices.
#
# B. Role of AI in improving farming practices and increasing yield
# By analyzing data on environmental conditions, crop performance, and market trends, AI can help farmers make informed decisions about seeding, irrigation, fertilization, and harvesting. AI technologies are also enabling precision agriculture techniques to maximize yield and minimize waste.
#
# VI. Challenges and opportunities in AI adoption in India
#
# A. Infrastructure and data security concerns
# One of the key challenges for AI adoption in India is the lack of adequate infrastructure, skilled workforce, and data security measures. Companies need to invest in robust IT systems, data governance policies, and cybersecurity protocols to ensure the safe and responsible use of AI technologies.
#
# B. Government initiatives and policies promoting AI
# The Indian government has introduced initiatives such as the National AI Portal, National Program on AI, and AI Task Force to support the development and adoption of AI in the country. By creating a conducive environment for AI research, innovation, and entrepreneurship, India can harness the full potential of AI for economic growth and societal benefit.
#
# VII. Future of AI in India
#
# A. Potential for growth and innovation in AI technology
# As AI technologies continue to evolve and mature, the potential for growth and innovation in India is immense. With a young and tech-savvy population, a thriving startup ecosystem, and a supportive regulatory environment, India is well positioned to become a global leader in AI research and development.
#
# B. Role of Indian startups in AI development
# Indian startups are playing a key role in advancing AI technologies and applications in various sectors. By focusing on cutting-edge research, developing AI-powered solutions, and collaborating with industry partners, Indian startups are driving innovation and creating new opportunities for growth.
#
# VIII. Conclusion
#
# A. Summary of key points
# The rise of AI in India is transforming industries, driving economic growth, and improving quality of life for citizens. With advancements in AI technologies, adoption in key sectors, and government support for AI development, India is poised to emerge as a leading player in the global AI market.
#
# B. The promising future of AI in India
# As AI continues to revolutionize industries and shape the future of work, India has the potential to harness the power of AI for sustainable growth, social development, and global competitiveness. By investing in AI research, talent development, and innovation ecosystems, India can solidify its position as a frontrunner in the AI revolution.

# %% [markdown]
# # evaluate_blog

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str
    score: str

# %%
def evaluate_blog(state: BlogState) -> BlogState:
    prompt = f"""Based on the outline:\n{state['outline']}\n
Rate the following blog content:\n{state['content']}\n
Give a score out of 10 with explanation."""

    response = model.invoke(prompt).content.strip()

    state["score"] = response  
    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)
graph.add_node("evaluate_blog", evaluate_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge("create_blog", "evaluate_blog")
graph.add_edge("evaluate_blog", END)

workflow = graph.compile()

# %%
initial_state = {"title": "Rise of AI in India"}
final_state = workflow.invoke(initial_state)
print(final_state["outline"])
print(final_state["content"])
# Out:
# I. Introduction
#     A. Explanation of AI (Artificial Intelligence)
#     B. Brief overview of the current state of AI technology in India
#     C. Thesis statement - The rise of AI in India and its impact on various sectors
#
# II. History of AI in India
#     A. Brief history of AI technology in India
#     B. Major milestones in the development of AI in the country
#     C. Adoption of AI by Indian businesses and governmental organizations
#
# III. Current state of AI in India
#     A. Key players in the Indian AI industry
#     B. Major advancements in AI technology in India
#     C. Challenges faced by AI startups and companies in the country
#     D. Government initiatives to promote AI technology in India
#
# IV. Impact of AI on various sectors in India
#     A. Healthcare
#         1. AI-driven healthcare solutions in India
#         2. Improvements in patient care and diagnosis
#     B. Education
#         1. Implementations of AI in Indian educational institutions
#         2. Enhancements in personalized learning and student outcomes
#     C. Finance
#         1. AI applications in the Indian finance industry
#         2. Benefits of AI in fraud detection and risk management
#     D. Manufacturing
#         1. Automation and AI in the Indian manufacturing sector
#         2. Increased efficiency and productivity in manufacturing processes
#
# V. Future of AI in India
#     A. Predictions for the growth of AI technology in India
#     B. Potential challenges and opportunities in the integration of AI in various sectors
#     C. Ethical considerations and regulations for the use of AI in India
#
# VI. Conclusion
#     A. Recap of key points discussed in the blog
#     B. Final thoughts on the rise of AI in India and its implications for the future
#     C. Call to action for readers to stay informed about AI developments in India and globally
#
#
# I. Introduction
#
# A. Explanation of AI (Artificial Intelligence)
# Artificial Intelligence (AI) is a branch of computer science that focuses on creating intelligent machines that can think, learn, and problem-solve like humans. AI algorithms are designed to analyze data, recognize patterns, and make decisions without human intervention.
#
# B. Brief overview of the current state of AI technology in India
# India has witnessed significant growth in the field of AI in recent years, with the country emerging as a key player in the global AI landscape. Indian companies and startups are leveraging AI technologies to innovate and transform various sectors, including healthcare, education, finance, and manufacturing.
#
# C. Thesis statement - The rise of AI in India and its impact on various sectors
# The rise of AI in India is reshaping industries and driving economic growth by enabling businesses to make smarter decisions, improve efficiency, and deliver better services to customers. This blog will explore the history of AI in India, the current state of AI technology, its impact on various sectors, and the future of AI in the country.
#
# II. History of AI in India
#
# A. Brief history of AI technology in India
# India has a rich history in the field of AI, with research and development efforts dating back to the early 1980s. The country's academic institutions and research organizations have made significant contributions to AI research, leading to breakthroughs in machine learning, robotics, and natural language processing.
#
# B. Major milestones in the development of AI in the country
# Over the years, India has achieved several milestones in the field of AI, including the establishment of AI research centers, the launch of AI-focused startups, and the adoption of AI technologies by leading Indian companies. The government has also initiated programs to promote AI research and development in the country.
#
# C. Adoption of AI by Indian businesses and governmental organizations
# Indian businesses and governmental organizations are increasingly embracing AI technologies to drive innovation and improve operational efficiency. From personalized healthcare solutions to intelligent education platforms, AI is helping to transform various industries and enhance the quality of services provided to customers.
#
# III. Current state of AI in India
#
# A. Key players in the Indian AI industry
# India boasts a vibrant AI ecosystem, with a growing number of startups, research labs, and tech companies leading the way in AI innovation. Companies like Wipro, TCS, Infosys, and startups like Niki.ai, RapidOwl, and Staqu are making significant strides in AI development and deployment.
#
# B. Major advancements in AI technology in India
# India has made significant advancements in AI technology, particularly in the areas of natural language processing, computer vision, and robotics. Indian researchers and engineers are actively contributing to the global AI community, publishing cutting-edge research papers and developing innovative AI solutions.
#
# C. Challenges faced by AI startups and companies in the country
# Despite the rapid growth of the AI industry in India, startups and companies face various challenges, including talent shortages, data privacy concerns, and regulatory hurdles. Access to funding and resources can also be limiting factors for AI startups looking to scale their operations and bring their innovations to market.
#
# D. Government initiatives to promote AI technology in India
# The Indian government has launched several initiatives to promote AI research and development in the country, including the National AI Portal, the National AI Strategy, and the AI Task Force. These initiatives aim to accelerate AI adoption, drive innovation, and create a conducive environment for AI startups and companies to thrive.
#
# IV. Impact of AI on various sectors in India
#
# A. Healthcare
# AI-driven healthcare solutions are revolutionizing the way medical professionals diagnose, treat, and care for patients in India. From predictive analytics to medical imaging, AI technologies are enabling healthcare providers to deliver personalized and efficient healthcare services to patients.
#
# B. Education
# AI is transforming the education sector in India by enabling personalized learning experiences, adaptive assessments, and virtual tutoring platforms. Educational institutions are leveraging AI technologies to improve student outcomes, enhance teaching methods, and streamline administrative processes.
#
# C. Finance
# The finance industry in India is leveraging AI applications to enhance fraud detection, risk management, and customer service. AI-powered algorithms are helping financial institutions to analyze vast amounts of data, identify patterns, and make informed decisions to mitigate risks and improve operational efficiency.
#
# D. Manufacturing
# Automation and AI are reshaping the manufacturing sector in India by enabling smart factories, predictive maintenance, and quality control solutions. AI technologies like robotics, machine learning, and IoT are driving efficiency, reducing costs, and increasing productivity in manufacturing processes.
#
# V. Future of AI in India
#
# A. Predictions for the growth of AI technology in India
# AI is expected to play a crucial role in India's digital transformation journey, with the market projected to grow significantly in the coming years. The adoption of AI technologies across industries is set to drive innovation, create new business opportunities, and improve the overall quality of life for Indian citizens.
#
# B. Potential challenges and opportunities in the integration of AI in various sectors
# As AI technologies continue to advance, there will be both challenges and opportunities for businesses and organizations in India. Issues such as data privacy, ethical considerations, and regulatory compliance will need to be addressed to ensure the responsible and sustainable deployment of AI solutions across sectors.
#
# C. Ethical considerations and regulations for the use of AI in India
# As AI technologies become more pervasive in Indian society, there is a growing need to establish ethical guidelines and regulations to govern their use. It is essential for policymakers, industry stakeholders, and the public to collaborate and ensure that AI technologies are developed and deployed in a responsible and ethical manner.
#
# VI. Conclusion
#
# A. Recap of key points discussed in the blog
# The rise of AI in India is reshaping industries, driving innovation, and transforming the way businesses operate and deliver services. From healthcare to finance, education to manufacturing, AI technologies are revolutionizing sectors and unlocking new opportunities for growth and development.
#
# B. Final thoughts on the rise of AI in India and its implications for the future
# The future of AI in India looks promising, with the country poised to become a global hub for AI innovation and research. By leveraging AI technologies, India can address complex challenges, improve efficiencies, and create a more inclusive and sustainable future for all.
#
# C. Call to action for readers to stay informed about AI developments in India and globally
# As AI technologies continue to evolve and shape the world we live in, it is essential for individuals to stay informed and engaged in the discourse around AI developments in India and globally. By staying informed, advocating for responsible AI practices, and participating in discussions on AI ethics and regulations, we can collectively ensure that AI technology benefits society as a whole.

# %%
initial_state = {
    "title": "Rise of AI in India",
    "outline": "",
    "content": ""
}
final_state = workflow.invoke(initial_state)

print(final_state["outline"])
print()
print("****************")
print()
print(final_state["content"])
print()
print("****************")
print()
print(final_state["score"])
# Out:
# I. Introduction
#     A. Brief overview of artificial intelligence (AI)
#     B. Explanation of the growing importance of AI in India
#     C. Thesis statement: The rise of AI in India is revolutionizing industries and transforming the country's economy
#
# II. Historical background of AI in India
#     A. Early adoption of AI technologies in India
#     B. Government initiatives to promote AI research and development
#     C. Collaboration between academia and industry in advancing AI technologies
#
# III. Current landscape of AI in India
#     A. Major players in the Indian AI industry
#     B. Applications of AI in various sectors such as healthcare, agriculture, finance, and manufacturing
#     C. Challenges and opportunities for AI adoption in India
#
# IV. Impact of AI on the Indian economy
#     A. Job displacement and creation due to AI automation
#     B. Increase in productivity and efficiency in industries
#     C. Potential for India to become a global AI hub
#
# V. Government policies and regulations on AI in India
#     A. Initiatives to promote AI research and development
#     B. Framework for ethical AI adoption and data privacy
#     C. Collaboration with international organizations for AI governance
#
# VI. Future prospects of AI in India
#     A. Emerging AI trends in India such as machine learning, robotics, and natural language processing
#     B. Opportunities for startups and small businesses in the AI sector
#     C. Strategies for individuals to upskill and prepare for the AI-driven future
#
# VII. Conclusion
#     A. Recap of key points discussed in the blog
#     B. Importance of AI in shaping the future of India
#     C. Call to action for readers to stay informed and engaged in the development of AI in India
#
# ****************
#
# Artificial Intelligence (AI) has emerged as a revolutionary technology that is transforming industries and shaping the future of countries around the world. In India, the rise of AI has gained significant momentum in recent years, with the government, industry, and academia all actively participating in the development and adoption of AI technologies. The growing importance of AI in India is evident in its impact on various sectors of the economy, its potential to create new opportunities for growth and innovation, and the challenges it poses in terms of job displacement and ethical concerns.
#
# Historical Background of AI in India
#
# India has a long history of early adoption of AI technologies, with research and development activities in AI dating back to the 1960s. The Indian government has been actively promoting AI research and development through initiatives such as the National AI Strategy, which aims to position India as a global leader in AI by 2030. Collaboration between academia and industry in advancing AI technologies has also played a crucial role in shaping the AI landscape in India.
#
# Current Landscape of AI in India
#
# The Indian AI industry is dominated by major players such as Tata Consultancy Services, Infosys, and Wipro, who are actively working on developing AI solutions for various sectors such as healthcare, agriculture, finance, and manufacturing. AI is being used in India to improve productivity and efficiency in industries, leading to better decision-making and increased competitiveness. However, there are challenges such as data privacy concerns, lack of skilled talent, and ethical considerations that need to be addressed for the successful adoption of AI in India.
#
# Impact of AI on the Indian Economy
#
# AI automation has the potential to displace jobs in traditional industries, but it also creates new opportunities for job creation in emerging sectors such as AI research and development. The increase in productivity and efficiency brought about by AI technologies is expected to bring significant economic benefits to India, positioning it as a global AI hub in the future.
#
# Government Policies and Regulations on AI in India
#
# The Indian government has taken several initiatives to promote AI research and development, including the establishment of the National AI Research Institute and the AI Garage program to support startups in the AI sector. There is also a framework for ethical AI adoption and data privacy in place to ensure that AI technologies are used responsibly and in the public interest. Collaboration with international organizations for AI governance is also being pursued to ensure that AI development in India is aligned with global standards.
#
# Future Prospects of AI in India
#
# The future of AI in India looks promising, with emerging trends such as machine learning, robotics, and natural language processing gaining traction in various sectors. There are opportunities for startups and small businesses to capitalize on the growing demand for AI solutions in India, and individuals can upskill and prepare for the AI-driven future by acquiring relevant skills and knowledge.
#
# Conclusion
#
# The rise of AI in India is transforming industries, creating new opportunities for growth and innovation, and shaping the future of the country's economy. It is important for stakeholders in India to stay informed and engaged in the development of AI to leverage its potential benefits and address its challenges. By working together, India can harness the power of AI to drive economic growth, boost innovation, and improve the quality of life for its citizens.
#
# ****************
#
# I would rate this blog content a 9 out of 10. The content covers a comprehensive overview of the rise of AI in India, including historical background, current landscape, impact on the economy, government policies, future prospects, and a compelling call to action. The content is well-structured, informative, and provides a balanced view of the opportunities and challenges brought about by AI in India. Overall, it is a well-written and insightful piece that effectively conveys the importance of AI in shaping the future of the country.

# %%
print(final_state.keys())
# Out:
# dict_keys(['title', 'outline', 'content', 'score'])
