# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

load_dotenv(override=True)
model = ChatOpenAI()

# %%
# Define State

class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
# Graph Setup
graph = StateGraph(BlogState)

# Add nodes
graph.add_node("create_outline", create_outline)
graph.add_node("create_blog", create_blog)

# Add edges
graph.add_edge(START, "create_outline")
graph.add_edge("create_outline", "create_blog")
graph.add_edge("create_blog", END)

# %%
workflow = graph.compile()

initial_state = {"title": "Rise of AI in India"}
final_state = workflow.invoke(initial_state)
print(final_state["outline"])
print(final_state["content"])
# Out:
# I. Introduction
#     A. Overview of artificial intelligence (AI)
#     B. Significance of AI in India
#     C. Purpose of the blog
#
# II. History and Progress of AI in India
#     A. Development of AI research in India
#     B. Establishment of AI laboratories and research centers
#     C. Collaboration with global AI companies
#
# III. Applications of AI in Various Sectors in India
#     A. Healthcare
#         1. AI in medical diagnosis
#         2. AI in personalized medicine
#     B. Education
#         1. AI in personalized learning
#         2. AI in assessment and evaluation
#     C. Finance
#         1. AI in fraud detection
#         2. AI in investment analysis
#     D. Agriculture
#         1. AI in crop monitoring
#         2. AI in pest control
#
# IV. Challenges and Opportunities for AI in India
#     A. Infrastructure and resources
#     B. Skilled workforce
#     C. Regulatory framework
#     D. Ethical considerations
#
# V. Government Initiatives to Promote AI in India
#     A. National AI strategy
#     B. Research grants and funding
#     C. Skill development programs
#     D. Collaboration with industry partners
#
# VI. Future of AI in India
#     A. Potential growth and impact of AI in India
#     B. Emerging trends in AI technology
#     C. Opportunities for innovation and entrepreneurship
#
# VII. Conclusion
#     A. Recap of key points discussed in the blog
#     B. Importance of AI in shaping the future of India
#     C. Call to action for readers to stay informed and engaged in developments in AI in India.
# In recent years, there has been a remarkable rise in the adoption and application of artificial intelligence (AI) in India. AI, the simulation of human intelligence processes by machines, has revolutionized various sectors including healthcare, education, finance, and agriculture. The integration of AI technologies has not only enhanced the efficiency and productivity of businesses but has also opened up new opportunities for innovation and growth in the country.
#
# This blog aims to explore the rise of AI in India, from its history and progress to the challenges and opportunities it presents, as well as the government initiatives in promoting AI, and the future of AI in the country.
#
# History and Progress of AI in India
#
# India has a rich history of research and development in the field of artificial intelligence. The establishment of AI research laboratories and centers such as the Indian Institute of Science (IISc) in Bangalore and the Indian Statistical Institute (ISI) in Kolkata have played a significant role in advancing AI research in the country. The collaboration between Indian researchers and global AI companies has further accelerated the growth of AI in India.
#
# Applications of AI in Various Sectors in India
#
# AI has found applications in various sectors in India, transforming the way businesses operate and deliver services. In healthcare, AI is being used for medical diagnosis and personalized medicine, improving patient outcomes and reducing healthcare costs. In education, AI is facilitating personalized learning experiences for students and enhancing assessment and evaluation processes. In finance, AI is being used for fraud detection and investment analysis, helping financial institutions make informed decisions. In agriculture, AI is assisting farmers in crop monitoring and pest control, leading to increased yields and sustainable farming practices.
#
# Challenges and Opportunities for AI in India
#
# Despite the rapid growth of AI in India, there are challenges that need to be addressed to fully realize its potential. The lack of infrastructure and resources, shortage of skilled workforce, regulatory framework, and ethical considerations are some of the challenges that need to be overcome. However, these challenges also present opportunities for innovation and growth in the AI sector in India.
#
# Government Initiatives to Promote AI in India
#
# The Indian government has recognized the importance of AI in shaping the future of the country and has taken several initiatives to promote its adoption and development. The National AI strategy, research grants, funding, skill development programs, and collaboration with industry partners are some of the key initiatives that have been implemented to support the growth of AI in India.
#
# Future of AI in India
#
# The future of AI in India is promising, with potential for significant growth and impact on various sectors of the economy. Emerging trends in AI technology such as machine learning, natural language processing, and robotics are expected to drive further innovation and entrepreneurship in the country. There are ample opportunities for businesses and entrepreneurs to leverage AI technologies to enhance their operations and deliver value to customers.
#
# In conclusion, the rise of AI in India presents a world of opportunities for growth, innovation, and development. As AI continues to transform various sectors of the economy, it is important for stakeholders to stay informed and engaged in the developments in the field. By collaborating and investing in AI, India has the potential to become a global leader in artificial intelligence and shape the future of the country.

# %% [markdown]
# # evaluate_blog

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str
    score: str

# %%
def evaluate_blog(state: BlogState) -> BlogState:
    prompt = f"""Based on the outline:\n{state['outline']}\n
Rate the following blog content:\n{state['content']}\n
Give a score out of 10 with explanation."""

    response = model.invoke(prompt).content.strip()

    state["score"] = response  
    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)
graph.add_node("evaluate_blog", evaluate_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge("create_blog", "evaluate_blog")
graph.add_edge("evaluate_blog", END)

workflow = graph.compile()

# %%
initial_state = {"title": "Rise of AI in India"}
final_state = workflow.invoke(initial_state)
print(final_state["outline"])
print(final_state["content"])
# Out:
# I. Introduction
#     A. Brief overview of AI technology
#     B. Growing importance of AI in India
#     C. Purpose of the blog
#
# II. Historical context of AI in India
#     A. Early developments in AI technology in India
#     B. Adoption of AI in various industries
#     C. Government initiatives to promote AI research and development
#
# III. Current landscape of AI in India
#     A. Key players in the AI industry in India
#     B. Adoption of AI in sectors such as healthcare, finance, and agriculture
#     C. Challenges faced by the AI industry in India
#
# IV. Rise of AI startups in India
#     A. Emerging AI startups in India
#     B. Success stories of AI startups in India
#     C. Impact of AI startups on the Indian economy
#
# V. Future outlook for AI in India
#     A. Potential growth opportunities for AI in India
#     B. Government policies to support the growth of AI in India
#     C. Impact of AI on job market and workforce in India
#
# VI. Conclusion
#     A. Recap of key points discussed in the blog
#     B. Importance of AI in shaping the future of India
#     C. Call to action for readers to stay informed about AI developments in India.
# I. Introduction
#
# A. Artificial Intelligence (AI) technology refers to machines that are designed to simulate human thinking and behavior, with the ability to learn from data and improve performance over time. AI has become increasingly important in various industries around the world, as it has the potential to revolutionize processes, increase efficiency, and drive innovation.
#
# B. In India, the importance of AI is growing rapidly due to the country's large pool of skilled technology professionals and the government's push towards digital transformation. AI has the potential to transform sectors such as healthcare, finance, agriculture, and manufacturing in India.
#
# C. The purpose of this blog is to provide an overview of the rise of AI in India, highlighting the historical context, current landscape, and future outlook for AI technology in the country. By understanding the growth of AI in India, readers can gain insights into the potential impact of this technology on the Indian economy and society.
#
# II. Historical context of AI in India
#
# A. India has a rich history of AI research and development, with several institutions and research centers working on AI technologies since the 1980s. The Indian Institute of Technology (IIT) and Indian Institute of Science (IISc) have been at the forefront of AI research in the country.
#
# B. Over the years, AI has been adopted in various industries in India, including healthcare, finance, and agriculture. For example, AI-powered healthcare solutions are being used to improve patient care and diagnosis, while AI algorithms are being used in the financial sector for fraud detection and risk assessment.
#
# C. The Indian government has also taken initiatives to promote AI research and development in the country. The National AI Strategy aims to make India a global hub for AI innovation, by investing in research centers, training programs, and infrastructure development.
#
# III. Current landscape of AI in India
#
# A. India is home to several key players in the AI industry, including multinational companies such as Google, Microsoft, and IBM, as well as domestic startups like Flipkart, Zomato, and Swiggy. These companies are investing in AI technologies to improve their products and services, and drive growth in the Indian market.
#
# B. AI is being adopted in various sectors in India, such as healthcare, finance, and agriculture. For example, AI-powered chatbots are being used in healthcare to provide remote consultations, while AI algorithms are being used in finance to analyze market trends and make investment decisions.
#
# C. Despite the growth of AI in India, the industry faces challenges such as data privacy concerns, lack of skilled professionals, and ethical implications of AI technologies. It is important for companies and policymakers to address these challenges to ensure the responsible and sustainable use of AI in India.
#
# IV. Rise of AI startups in India
#
# A. In recent years, there has been a rise in AI startups in India, focusing on a wide range of applications such as healthcare, education, and e-commerce. These startups are leveraging AI technologies such as machine learning, natural language processing, and computer vision to develop innovative solutions for the Indian market.
#
# B. Some AI startups in India have achieved global success, such as Niramai Health Analytix, which uses AI to detect early-stage breast cancer, and SigTuple, which develops AI-powered solutions for medical diagnosis. These success stories are inspiring other entrepreneurs and investors to invest in AI startups in India.
#
# C. The rise of AI startups in India is expected to have a positive impact on the Indian economy, by creating jobs, driving innovation, and attracting foreign investment. These startups have the potential to transform traditional industries and drive growth in emerging sectors, such as AI research and development.
#
# V. Future outlook for AI in India
#
# A. The future outlook for AI in India is promising, with the potential for significant growth and development in the coming years. The government's focus on digital transformation and AI adoption is expected to create new opportunities for businesses and startups in India.
#
# B. Government policies such as the National AI Strategy and the National Digital Health Mission are expected to support the growth of AI in India by investing in research and development, promoting collaboration between industry and academia, and creating a conducive regulatory environment for AI technologies.
#
# C. The impact of AI on the job market and workforce in India is a topic of debate, with some experts predicting that AI technologies will replace traditional jobs, while others believe that AI will create new job opportunities and enhance productivity. It is important for policymakers and businesses to address these challenges and ensure that the workforce is prepared for the AI-driven economy.
#
# VI. Conclusion
#
# A. In conclusion, the rise of AI in India presents new opportunities for businesses, startups, and policymakers to drive innovation, improve efficiency, and enhance competitiveness in the global market. By staying informed about the developments in AI technology in India, readers can prepare themselves for the future challenges and opportunities that AI will bring.
#
# B. AI has the potential to shape the future of India by transforming traditional industries, creating new markets, and driving economic growth. It is important for India to leverage its strengths in technology and innovation to become a global leader in AI research and development.
#
# C. I encourage readers to stay informed about the latest developments in AI technology in India, by following news articles, research reports, and industry events. By understanding the impact of AI on the Indian economy and society, readers can contribute to the responsible and sustainable adoption of AI technologies in India.

# %%
initial_state = {
    "title": "Rise of AI in India",
    "outline": "",
    "content": ""
}
final_state = workflow.invoke(initial_state)

print(final_state["outline"])
print(final_state["content"])
print(final_state["score"])
# Out:
# I. Introduction
#     A. Definition of AI
#     B. Overview of the rise of AI in India
#     C. Purpose of the blog post
#
# II. Historical Perspective of AI in India
#     A. Early developments in AI in India
#     B. Adoption of AI in various sectors
#     C. Key players in the AI industry in India
#
# III. Current State of AI in India
#     A. Growth of AI startups in India
#     B. Emerging trends in AI in India
#     C. Government initiatives to promote AI in India
#
# IV. Impact of AI on Indian Society and Economy
#     A. Job displacement and creation
#     B. Automation of various industries
#     C. Ethical and social implications of AI in India
#
# V. Challenges and Opportunities in the AI Industry in India
#     A. Skill gap in AI workforce
#     B. Regulation and policy challenges
#     C. Collaboration opportunities for Indian AI companies
#
# VI. Future Outlook of AI in India
#     A. Predictions for the growth of AI in India
#     B. Potential use cases for AI in India
#     C. Strategies for leveraging AI for sustainable development in India
#
# VII. Case Studies of Successful AI Implementation in India
#     A. Healthcare sector
#     B. Agriculture sector
#     C. Finance sector
#
# VIII. Conclusion
#     A. Recap of key points discussed in the blog post
#     B. Final thoughts on the rise of AI in India
#     C. Call to action for readers to stay updated on developments in the AI industry in India.
# I. Introduction
#
# A. Definition of AI: Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, especially computer systems. These processes include learning, reasoning, and self-correction.
#
# B. Overview of the rise of AI in India: Over the past decade, India has witnessed a significant rise in the adoption and growth of AI technologies across various sectors. From healthcare to agriculture to finance, AI is revolutionizing the way businesses operate and society functions.
#
# C. Purpose of the blog post: The purpose of this blog post is to provide an in-depth analysis of the rise of AI in India, exploring its historical perspective, current state, impact on society and economy, challenges and opportunities, future outlook, successful case studies, and concluding thoughts on the subject.
#
# II. Historical Perspective of AI in India
#
# A. Early developments in AI in India: India has a rich history of AI research and development, with institutions like the Indian Institutes of Technology (IITs) and the Indian Statistical Institute (ISI) playing a significant role in the early days of AI in the country.
#
# B. Adoption of AI in various sectors: In recent years, there has been a rapid adoption of AI technologies in various sectors such as healthcare, agriculture, finance, education, and manufacturing. Companies are increasingly integrating AI into their operations to improve efficiency and productivity.
#
# C. Key players in the AI industry in India: India is home to a plethora of AI startups and companies making waves in the global AI industry. Companies like Flipkart, Zomato, and Ola are using AI to enhance customer experience and streamline operations.
#
# III. Current State of AI in India
#
# A. Growth of AI startups in India: The Indian startup ecosystem has seen a surge in AI startups in recent years, with a focus on areas like healthcare, fintech, and e-commerce. These startups are attracting significant investment and driving innovation in the AI space.
#
# B. Emerging trends in AI in India: Some of the emerging trends in AI in India include the rise of conversational AI, AI-powered analytics, and AI for social good. These trends are shaping the future of AI in the country.
#
# C. Government initiatives to promote AI in India: The Indian government has launched initiatives like the National AI Portal and the National Programme on AI to promote the adoption and development of AI technologies in the country.
#
# IV. Impact of AI on Indian Society and Economy
#
# A. Job displacement and creation: AI is expected to disrupt traditional job roles and create new job opportunities in India. While there is a concern about job displacement, AI is also creating new roles in areas like data science, AI development, and AI strategy.
#
# B. Automation of various industries: AI is driving automation in various industries, leading to increased efficiency and productivity. Industries like manufacturing, healthcare, and agriculture are leveraging AI to streamline processes and improve outcomes.
#
# C. Ethical and social implications of AI in India: The rise of AI in India raises ethical and social concerns around data privacy, bias in AI algorithms, and the impact of AI on marginalized communities. It is crucial for policymakers and industry leaders to address these issues as AI becomes more pervasive.
#
# V. Challenges and Opportunities in the AI Industry in India
#
# A. Skill gap in AI workforce: There is a significant skill gap in the AI workforce in India, with a shortage of professionals trained in AI technologies. Addressing this skill gap is crucial for the continued growth of the AI industry in the country.
#
# B. Regulation and policy challenges: India lacks comprehensive regulations and policies around AI, leading to uncertainty and challenges for AI companies. Developing a robust regulatory framework is essential for fostering a conducive environment for AI innovation.
#
# C. Collaboration opportunities for Indian AI companies: Indian AI companies have opportunities to collaborate with international counterparts and leverage global expertise to drive innovation and growth in the AI industry. Collaborations can help Indian companies expand their reach and scale their operations.
#
# VI. Future Outlook of AI in India
#
# A. Predictions for the growth of AI in India: The future of AI in India looks promising, with projections showing significant growth in the adoption of AI technologies across sectors. AI is expected to drive innovation, improve efficiency, and create new business opportunities in the country.
#
# B. Potential use cases for AI in India: AI has a wide range of potential use cases in India, including personalized healthcare, precision agriculture, smart cities, and financial inclusion. These use cases have the potential to address key societal challenges and drive economic growth.
#
# C. Strategies for leveraging AI for sustainable development in India: To leverage AI for sustainable development in India, it is crucial to focus on creating ethical AI frameworks, promoting diversity in AI workforce, and investing in AI research and development. These strategies can help ensure that AI is used responsibly and equitably for the benefit of society.
#
# VII. Case Studies of Successful AI Implementation in India
#
# A. Healthcare sector: AI is being used in the healthcare sector in India for tasks like medical imaging analysis, predictive analytics, and personalized medicine. Companies like Practo and SigTuple are using AI to revolutionize healthcare delivery in the country.
#
# B. Agriculture sector: AI is transforming agriculture in India by enabling precision farming, crop monitoring, and pest detection. Startups like CropIn and Emotix are developing AI solutions to improve crop yield and farmer livelihoods.
#
# C. Finance sector: AI is disrupting the finance sector in India with applications in fraud detection, credit scoring, and algorithmic trading. Companies like Paytm and PolicyBazaar are leveraging AI to enhance customer experience and drive innovation in the financial services industry.
#
# VIII. Conclusion
#
# A. Recap of key points discussed in the blog post: The rise of AI in India is reshaping industries, driving innovation, and creating new opportunities for growth. From the healthcare sector to finance to agriculture, AI is revolutionizing the way businesses operate and society functions.
#
# B. Final thoughts on the rise of AI in India: As AI becomes more pervasive in India, it is essential for policymakers, industry leaders, and society to collaborate and address the challenges and opportunities that come with AI adoption. By working together, India can harness the power of AI for sustainable development and inclusive growth.
#
# C. Call to action for readers to stay updated on developments in the AI industry in India: To stay informed about the latest developments in the AI industry in India, readers are encouraged to follow leading AI companies and research organizations, attend AI conferences and events, and engage with AI communities online. Keeping pace with AI trends and advancements will help individuals and businesses tap into the immense potential of AI for driving innovation and growth in India.
# I would rate this blog content a 9 out of 10. The outline is comprehensive and covers all key aspects related to the rise of AI in India, from historical perspective to current state, impact on society and economy, challenges and opportunities, future outlook, successful case studies, and a conclusion with a call to action. The content is well-structured and informative, providing a detailed analysis of the topic. The only slight improvement could be in providing more specific examples or statistics to further support the points made in each section. Overall, a well-rounded and insightful blog post.

# %%
print(final_state.keys())
# Out:
# dict_keys(['title', 'outline', 'content'])
